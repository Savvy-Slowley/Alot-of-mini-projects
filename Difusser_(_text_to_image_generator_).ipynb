# %% [markdown]
# <a href="https://colab.research.google.com/github/Savvy-Slowley/Alot-of-mini-projects/blob/main/Difusser_(_text_to_image_generator_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### https://github.com/huggingface/diffusers

# %%
# !pip install diffusers transformers

# %%
# %matplotlib inline
from diffusers import DiffusionPipeline
import matplotlib.pyplot as plt

# %%
#text to image diffuser models
model_id = "CompVis/ldm-text2im-large-256"

# %%
# load model and scheduler
ldm = DiffusionPipeline.from_pretrained(model_id)
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.96k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/118k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/108k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/98.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/80.8k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/713 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.49G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/468 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/343M [00:00<?, ?B/s]
# ...

# %%
# run pipeline in inference (sample random noise and denoise)
prompt = "A painting of a squirrel eating a burger" # What the image is
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(images[0])

# %%
# run pipeline in inference (sample random noise and denoise)
prompt = "Lion with money" # What the image is
images = ldm([prompt], num_inference_steps=50, eta=0.3, guidance_scale=6)["sample"]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.imshow(images[0])
